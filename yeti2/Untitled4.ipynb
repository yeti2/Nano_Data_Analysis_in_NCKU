# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x = linspace(0.01,1,100)

# %%
def f1(a):
    plot(x,x**a,'r')

# %%
f1(3)

# %%
from IPython.html.widgets import interact

# %%
interact(f1,a=(1,10.))

# %%
def f2(a,b):
    plot(x,x**(-a),'k') # comment
    plot(x,x**b,'r')
    ylim(0,10)

# %%
interact(f2,a=(1,10.),b=(1,10.))

# %%
def f3(a,b):
    x1 = linspace(0,b,1000)
    plot(a*sin(x1)*x1,a*cos(x1)*x1,'r')
    ylim(-(b*a),(b*a))

# %%
x = linspace(0,30,1000)

# %%
plot(sin(x)*x,cos(x)*x,'r')

# %%
interact(f3,a=(0.01,1.),b=(0,50.))

# %%
import pkg_resources

# %%
pkg_resources.get_distribution("sympy").version
# Out:
# '0.7.5'

# %%
from sympy.interactive import printing

# %%
printing.init_printing(use_latex=True)

# %%
from IPython.display import display

# %%
from sympy import integrate

# %%
from sympy import Symbol

# %%
x = Symbol('x')

# %%
integrate(2*x,x)
# Out:
#  2
# x

# %%
integrate(x/(cos(x)**2),x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-1e3e53ff119d> in <module>()
# ----> 1 integrate(x/(cos(x)**2),x)
#
# AttributeError: cos

# %%
from sympy import limit, sin, cos, exp, tan

# %%
integrate(1/(cos(x)**2),x)
# Out:
# sin(x)
# ──────
# cos(x)

# %%
from sympy import diff

# %%
diff(exp(x),x)
# Out:
#  x
# ℯ

# %%
diff(x**x,x)
# Out:
#  x
# x ⋅(log(x) + 1)

# %%
integrate(x**x,x)
# Out:
# ⌠
# ⎮  x
# ⎮ x  dx
# ⌡

# %%
from scipy.integrate import odeint
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
alpha=0.1
beta=0.015
gamma=0.0225
delta=0.02
def system(z,t):
    x,y=z[0],z[1]
    dxdt= x*(alpha-beta*y)
    dydt=-y*(gamma-delta*x)
    return [dxdt,dydt]

t=np.linspace(0,300.,1000)
x0,y0=1.0,1.0
sol=odeint(system,[x0,y0],t)

# %%
X,Y=sol[:,0],sol[:,1]
plt.plot(X,Y)
plt.show()

# %%
import random

# %% [raw]
# rand(1)

# %%
x = rand(1)

# %%
x
# Out:
# array([ 0.98052621])

# %%
rand(5,2)
# Out:
# array([[ 0.11706602,  0.09593326],
#        [ 0.09883713,  0.1942767 ],
#        [ 0.39219134,  0.47665097],
#        [ 0.11450786,  0.31564838],
#        [ 0.44995144,  0.29300137]])

# %%
def sim_pi(N):
    a = rand(N,2)
    p=0
    for i in range(N):
        if a[i,0]**2+a[i,1]**2<1:
            p = p+1
            plot(a[i,0],a[i,1],'rx')
        else:
            plot(a[i,0],a[i,1],'bx')
    p=4*p/float(N)
    c = linspace(0,1,100)
    plot(c,sqrt(1-c**2),'k')
    xlim(0,1)
    ylim(0,1)
    axis('equal')
    print "Estimation of Pi:" , p

# %%
sim_pi(10000)
# Out:
# Estimation of Pi: 3.1416

# %%
interact(sim_pi,N=(1,500))
# Out:
# Estimation of Pi: 3.05263157895

# %%
from sympy import oo

# %%
x = Symbol('x')

# %%
limit(sin(x)/x,x,0)
# Out:
# 1

# %%
from scipy.integrate import odeint
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
pi = np.pi
sqrt = np.sqrt
cos = np.cos
sin = np.sin

def deriv_z(z, phi):
    u, udot = z
    return [udot, -u + sqrt(u)]

phi = np.linspace(0, 7.0*pi, 2000)
zinit = [1.49907, 0]
z = odeint(deriv_z, zinit, phi)
u, udot = z.T
# plt.plot(phi, u)
fig, ax = plt.subplots()
ax.plot(1/u*cos(phi), 1/u*sin(phi))
ax.set_aspect('equal')
plt.grid(True)
plt.show()
